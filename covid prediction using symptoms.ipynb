# %% [markdown]
# # LINEAR REGRESSION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import seaborn as sns

# %%
data = pd.read_csv("dataset.csv")

# %%
data.head()
# Out:
#    temperature  oxidiation  status
# 0         98.0         100       0
# 1         98.1         100       0
# 2         98.2          99       0
# 3         98.3          99       0
# 4         98.4          98       0

# %%
from sklearn.linear_model import LinearRegression

# %%
data.shape
# Out:
# (76, 3)

# %%
data.plot("temperature", "status")
# Out:
# <AxesSubplot:xlabel='temperature'>

# %%
data.plot("oxidiation","status")
# Out:
# <AxesSubplot:xlabel='oxidiation'>

# %%
data.describe()
# Out:
#        temperature  oxidiation     status
# count    76.000000   76.000000  76.000000
# mean    100.973684   80.578947   0.736842
# std       2.368536   11.821182   0.443273
# min      97.000000   60.000000   0.000000
# 25%      98.875000   71.000000   0.000000
# 50%     101.000000   81.000000   1.000000
# 75%     103.025000   90.250000   1.000000
# max     104.900000  100.000000   1.000000

# %%
x = data[['temperature','oxidiation']].values
y = data['status'].values

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
sns.distplot(data['status'])
# Out:
# C:\Users\SH\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='status', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
y_pred = model.predict(x_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

df1 = df.head()

# %%
df.head(27)
# Out:
#     Actual  Predicted
# 0        1   0.964686
# 1        1   0.984006
# 2        1   0.461765
# 3        1   1.288189
# 4        1   0.578801
# 5        1   0.539789
# 6        1   1.272733
# 7        1   0.972414
# 8        1   0.644954
# 9        0   0.321265
# 10       1   0.824373
# 11       1   1.069945
# 12       1   0.793182
# 13       1   0.765855
# 14       1   0.641090
# 15       1   1.245499

# %%
df.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error: 0.29477629186029913

# %% [markdown]
# # SVM algorithm

# %%
data = pd.read_csv("dataset.csv")

# %%
data.head(26)
# Out:
#     temperature  oxidiation  status
# 0          98.0         100       0
# 1          98.1         100       0
# 2          98.2          99       0
# 3          98.3          99       0
# 4          98.4          98       0
# 5          98.5          98       0
# 6          98.6          97       0
# 7          98.7          97       0
# 8          98.8          96       0
# 9          98.9          96       0
# 10         97.0          95       0
# 11         97.1          95       0
# 12         97.2          94       0
# 13         97.3          94       0
# 14         97.4          93       0
# 15         97.5          93       0
# 16         97.6          92       0
# 17         97.7          92       0
# 18         97.8          91       0
# 19         97.9          90       0
# 20         99.1          89       1
# 21         99.2          89       1
# 22         99.3          88       1
# 23         99.4          87       1
# 24         99.5          86       1
# 25         99.6          85       1

# %%
data.shape
# Out:
# (76, 3)

# %%
x = data[['temperature','oxidiation']].values
y = data['status'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %%
from sklearn.svm import SVC

# %%
svclassifier = SVC(kernel='linear')
svclassifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 4  0]
#  [ 0 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %%
####### Random Forest Alogorithm

# %%
# !pip install keras

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('dataset.csv')

# %%
data.head()
# Out:
#    temperature  oxidiation  status
# 0         98.0         100       0
# 1         98.1         100       0
# 2         98.2          99       0
# 3         98.3          99       0
# 4         98.4          98       0

# %%
x = data[['temperature','oxidiation']].values
y = data['status'].values

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
regressor = RandomForestClassifier(n_estimators=200)
regressor.fit(x_train,y_train)
print (regressor.score(x_test,y_test))
# Out:
# 1.0

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.1875
# Mean Squared Error: 0.1875
# Root Mean Squared Error: 0.4330127018922193

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[ 1  0]
#  [ 3 12]]
#               precision    recall  f1-score   support
#
#            0       0.25      1.00      0.40         1
#            1       1.00      0.80      0.89        15
#
#     accuracy                           0.81        16
#    macro avg       0.62      0.90      0.64        16
# weighted avg       0.95      0.81      0.86        16
#
# 0.8125

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8125
